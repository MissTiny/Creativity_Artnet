# %%
import pandas as pd
import os
import numpy as np
from datetime import datetime
import ast
from googletrans import Translator
from concurrent.futures import ThreadPoolExecutor, as_completed
import asyncio, random
from concurrent.futures import ProcessPoolExecutor
from concurrent.futures import ThreadPoolExecutor
from transformers import CLIPTokenizer, CLIPTextModel
from openai import OpenAI
import json
import re
import anthropic
import torch
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity

# %%
artnet_2024 = pd.read_excel("D:\\MissTiny\\GitHub\\Creativity_Artnet\\Datasets\\ArtNet\\Artnet_Europe_2024_merged.xlsx")

# %%
artnet_2024.columns
# Out:
# Index(['artwork id', 'artist id', 'first', 'last', 'nationality', 'year born',
#        'year died', 'title', 'workyear modifier', 'workyear from',
#        'workyear to', 'est lo usd', 'est hi usd', 'sale price usd', 'artist',
#        'price'],
#       dtype='object')

# %%
artist_list = artnet_2024["artist"].value_counts()

# %%
for artist in artist_list.index:
    if "Gentileschi".lower() in artist.lower():
        print(artist)
# Out:
# Artemisia Gentileschi

# %%
artist_list[artist_list.index == "Artemisia Gentileschi"]
# Out:
# artist
# Artemisia Gentileschi    3
# Name: count, dtype: int64

# %%
min(artnet_2024["workyear from"])
# Out:
# 1400

# %%
artist_list[15:20]
# Out:
# artist
# Friedensreich Hundertwasser    2880
# Max Ernst                      2816
# Käthe Kollwitz                 2753
# Jean Dubuffet                  2492
# Giovanni Battista Piranesi     2346
# Name: count, dtype: int64
