# %%
import pandas as pd
import os
import numpy as np
from datetime import datetime
import ast
from googletrans import Translator
from concurrent.futures import ThreadPoolExecutor, as_completed
import asyncio, random
from concurrent.futures import ProcessPoolExecutor
from concurrent.futures import ThreadPoolExecutor
from transformers import CLIPTokenizer, CLIPTextModel
from openai import OpenAI
import json
import re
import anthropic
import torch
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity
from google import genai
from google.genai import types
import copy

# %%
artnet_2024 = pd.read_excel("D:\\MissTiny\\GitHub\\Creativity_Artnet\\Datasets\\ArtNet\\Artnet_Europe_2024_merged.xlsx")

# %%
artnet_2024.columns
# Out:
# Index(['artwork id', 'artist id', 'first', 'last', 'nationality', 'year born',
#        'year died', 'title', 'workyear modifier', 'workyear from',
#        'workyear to', 'est lo usd', 'est hi usd', 'sale price usd', 'artist',
#        'price'],
#       dtype='object')

# %% [markdown]
# # Test on Consistency

# %%
Artist_name = "Karel Appel"

# %%
artnet_2024_Renoir = artnet_2024[artnet_2024["artist"] == Artist_name].reset_index(drop=True)

# %%
artnet_2024_limit=copy.deepcopy(artnet_2024_Renoir)

# %%
artnet_2024_limit
# Out:
#       artwork id  artist id  first   last nationality  year born  year died  \
# 0             89       1579  Karel  Appel       Dutch       1921       2006
# 1            311       1579  Karel  Appel       Dutch       1921       2006
# 2            800       1579  Karel  Appel       Dutch       1921       2006
# 3            863       1579  Karel  Appel       Dutch       1921       2006
# 4           1154       1579  Karel  Appel       Dutch       1921       2006
# ...          ...        ...    ...    ...         ...        ...        ...
# 3003   444930964       1579  Karel  Appel       Dutch       1921       2006
# 3004   444931246       1579  Karel  Appel       Dutch       1921       2006
# 3005   444931247       1579  Karel  Appel       Dutch       1921       2006
# 3006   444931248       1579  Karel  Appel       Dutch       1921       2006
# 3007   444931249       1579  Karel  Appel       Dutch       1921       2006
#
#                                         title workyear modifier  \
# 0                                  Utan titel               NaN
# 1                     Flowers as a still life               NaN
# 2                                   TIGERBIRD               NaN
# 3                            Screaming animal               NaN
# 4                        Untitled Composition               NaN
# ...                                       ...               ...
# 3003                                 RED FACE             CIRCA
# 3004  PRESQUE UNE TÊTE, FROM PAYSAGES HUMAINS             CIRCA
# 3005                                 UNTITLED               NaN
# 3006                         BLUE FACED BEAST               NaN
# 3007                       SAD CAT, FROM CATS               NaN
#
#       workyear from  workyear to     est lo usd     est hi usd  \
# 0              1956          NaN   49602.472382   56688.539865
# 1              1978       1978.0   43570.240125   64210.671543
# 2              1952          NaN  380833.689049  509360.160119
# 3              1954       1954.0  122009.006482  173900.508509
# 4              1983          NaN   30000.000000   40000.000000
# ...             ...          ...            ...            ...
# 3003           1975          NaN     292.120061     438.180092
# 3004           1960          NaN     215.208034     286.944046
# 3005           1969          NaN     286.944046     430.416069
# 3006           1971          NaN     286.944046     430.416069
# 3007           1979          NaN     215.208034     286.944046
#
#       sale price usd       artist          price
# 0       68026.247838  Karel Appel  109263.111408
# 1       60984.113648  Karel Appel   95511.607909
# 2      520383.842954  Karel Appel  659857.178027
# 3      141824.867244  Karel Appel  211495.191648
# 4       30000.000000  Karel Appel   39704.620344
# ...              ...          ...            ...
# 3003     1167.749945  Karel Appel    1167.749945
# 3004      403.873745  Karel Appel     403.873745
# 3005      459.110473  Karel Appel     459.110473
# 3006      761.836442  Karel Appel     761.836442
# 3007      672.166428  Karel Appel     672.166428
#
# [3008 rows x 16 columns]

# %%
with open("D:\\MissTiny\\GitHub\\Creativity_Artnet\\Token_Key\\gemini_api_scp.txt", "r", encoding="utf-8") as file:
    gemini_api = file.read()

# %%
gemini_client = genai.Client(
    api_key=gemini_api
)

# %%
def annotation(i,content):
    row=[content["artwork id"],content["title"],content['first'],content['last'],content['workyear from'],content["nationality"]]

    instruction_message=fr"""You are an expert in artwork criticism, art history, and creativity evaluation.
    Using web search, find authoritative commentary on the artistic value and creative significance of the artwork:
    - Title: \'{content["title"]}\' 
    - Artist:{content['first']} {content['last']} ({content["nationality"]})
    - Year of Creation:{content['workyear from']} 
    
    Based strictly on information gathered through web search, summarize the consensus and key scholarly interpretations in English regarding the artwork’s artistic value and creativity.
    Your analysis should address innovations in composition, technique, emotional expression, iconography, and influences on later art.
    - An artwork is creative only if it is new, valuable, and surprising compared to prior artworks
    
    OUTPUT FORMAT(around 150 words each)

    **Artistic Value: <High or Low>**
    <Your summary here>
    
    **Creativity: <Yes or No>**
    <Your summary here>
    """ 
    grounding_tool = types.Tool(
        google_search=types.GoogleSearch()
    )
    
    config = types.GenerateContentConfig(
        tools=[grounding_tool]
    )
    response =gemini_client.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents=instruction_message,
        config=config,
    )
    try:
        answer = response.text
        artistic_answer = re.search(r"\*\*Artistic Value:\s*([^*]+)\*\*", answer)
        artistic_comment = re.search(r"\*\*Artistic Value:[^*]+\*\*\s*(.*?)\n\n\*\*Creativity", answer, re.S)
    
        creativity_answer = re.search(r"\*\*Creativity:\s*([^*]+)\*\*", answer)
        creativity_comment = re.search(r"\*\*Creativity:[^*]+\*\*\s*(.*)", answer, re.S)

        if not (artistic_answer and artistic_comment and creativity_answer and creativity_comment):
            row=[content["artwork id"], content["title"], content['first'], content['last'], content['workyear from'], content["nationality"],"","","",""]
            return i, row, answer
    except Exception as e:
        row=[content["artwork id"], content["title"], content['first'], content['last'], content['workyear from'], content["nationality"],"","","",""]
        return i, row, e
    
    result = {
        "artistic_value_answer": artistic_answer.group(1).strip() if artistic_answer else "",
        "artistic_value_comment": artistic_comment.group(1).strip() if artistic_comment else "",
        "creativity_answer": creativity_answer.group(1).strip() if creativity_answer else "",
        "creativity_comment": creativity_comment.group(1).strip() if creativity_comment else ""
    }

    row.append(result['artistic_value_answer'])
    row.append(result['artistic_value_comment'])
    row.append(result['creativity_answer'])
    row.append(result['creativity_comment'])
    return i, row, ""

# %%
# number_size= 5000
# number_size=df_raw.shape[0]
# range_start = 30000
range_start =850
# range_end = min(range_start+number_size,artnet_2024_Picasso.shape[0])
range_end = 1000
number_size = range_end - range_start
N = min(number_size, artnet_2024_limit.shape[0]-range_start)

# %%
error_output=[]
annotation_result = pd.DataFrame({
    "artwork id": np.full(number_size, np.nan, dtype=int),
    "title": [""] * number_size,
    "first": [""] * number_size,
    "last": [""] * number_size,
    "workyear from":np.full(number_size, np.nan, dtype=int),
    "nationality":[""] * number_size,
    "artistic_value_answer": [""] * number_size,
    "artistic_value_comment":[""] * number_size,
    "creativity_answer": [""] * number_size,
    "creativity_comment": [""] * number_size})
max_workers = 20  # tune to your CPU cores
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Parallel computation starts")
with ThreadPoolExecutor(max_workers=max_workers) as ex:
    futures = {
        ex.submit(annotation, i,
                   {
                "artwork id": artnet_2024_limit.iloc[i]["artwork id"],
                "title": artnet_2024_limit.iloc[i]["title"],
                "first": artnet_2024_limit.iloc[i]["first"],
                "last": artnet_2024_limit.iloc[i]["last"],
                "workyear from": artnet_2024_limit.iloc[i]["workyear from"],
                "nationality": artnet_2024_limit.iloc[i]["nationality"]}
                ): i
        for i in range(range_start,range_end)
    }
    
    completed = 0
    for fut in as_completed(futures):
        i,result,error = fut.result()
        annotation_result.loc[i-range_start]  = result
        if error !="":
            error_output.append(error)
        completed += 1
        if completed % 50 == 0:
            print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Completed {completed}/{len(artnet_2024_limit)}")
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Ends")
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: There are {len(error_output)} errors")
# Out:
# C:\Users\MissTiny\anaconda3\envs\Creativity\Lib\site-packages\numpy\_core\numeric.py:353: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(a, fill_value, casting='unsafe')
# 2025-12-16 04:26:02: Parallel computation starts
# 2025-12-16 04:26:14: Completed 50/3008
# 2025-12-16 04:26:23: Completed 100/3008
# 2025-12-16 04:26:33: Completed 150/3008
# 2025-12-16 04:26:33: Ends
# 2025-12-16 04:26:33: There are 0 errors

# %%
Artist_name.split(" ")[-1]
# Out:
# 'Appel'

# %%
annotation_result.iloc[0:150,].to_excel(f"comment_annotation_gemini_{Artist_name.split(" ")[-1]}_1000.xlsx",index=False)

# %% [markdown]
# # Merge

# %%
df1 = pd.read_excel(f"comment_annotation_gemini_{Artist_name.split(" ")[-1]}_100.xlsx")
df2 = pd.read_excel(f"comment_annotation_gemini_{Artist_name.split(" ")[-1]}_600.xlsx")
df3 = pd.read_excel(f"comment_annotation_gemini_{Artist_name.split(" ")[-1]}_650.xlsx")
df4 = pd.read_excel(f"comment_annotation_gemini_{Artist_name.split(" ")[-1]}_850.xlsx")
df5 = pd.read_excel(f"comment_annotation_gemini_{Artist_name.split(" ")[-1]}_1000.xlsx")

# %%
new_df = pd.concat([df1, df2,df3,df4,df5], axis=0, ignore_index=True)

# %%
new_df.to_excel(f"comment_annotation_gemini_{Artist_name.split(" ")[-1]}.xlsx",index=False)

# %% [markdown]
# # Check and Fix

# %%
empty_idx = annotation_result.index[annotation_result["artistic_value_answer"] == ""].tolist()

# %%
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: There are {len(empty_idx)} errors")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: There are {len(empty_idx)} errors")
#
# NameError: name 'empty_idx' is not defined

# %%
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Start")
count= 0
for error_index in empty_idx:
    if count%10 ==0:
        print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Current at {count}")
    content = {
                "artwork id": artnet_2024_limit.iloc[error_index]["artwork id"],
                "title": artnet_2024_limit.iloc[error_index]["title"],
                "first": artnet_2024_limit.iloc[error_index]["first"],
                "last": artnet_2024_limit.iloc[error_index]["last"],
                "workyear from": artnet_2024_limit.iloc[error_index]["workyear from"],
                "nationality": artnet_2024_limit.iloc[error_index]["nationality"]}
    _,result,error = annotation(error_index,content)
    annotation_result.loc[error_index,:] =result
    count+=1
    # if count ==10:
    #     break
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Ends")
# Out:
# 2025-12-15 22:56:53: Start
# 2025-12-15 22:56:53: Current at 0
# 2025-12-15 22:56:56: Ends

# %%
annotation_result.iloc[empty_idx]
# Out:
#      artwork id                                              title first  \
# 829   427154465  Nicolas Flamel (from Patrick Waldberg: Aux Pet...   Max
#
#       last  workyear from nationality artistic_value_answer  \
# 829  Ernst           1971      German                  High
#
#                                 artistic_value_comment creativity_answer  \
# 829  The artwork "Nicolas Flamel (from Patrick Wald...               Yes
#
#                                     creativity_comment
# 829  Max Ernst's "Nicolas Flamel (from Patrick Wald...

# %%
annotation_result.index[annotation_result["artistic_value_answer"] == ""].tolist()
# Out:
# []

# %%
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: There are {len(annotation_result.index[annotation_result["artistic_value_answer"] == ""].tolist())} errors")
# Out:
# 2025-11-28 07:48:23: There are 0 errors

# %% [markdown]
# # Error Fix

# %% [markdown]
# artnet_2024_Picasso = pd.read_excel("D:\\MissTiny\\GitHub\\Creativity_Artnet\\Datasets\\ArtNet\\Artnet_Europe_2024_Picasso.xlsx")

# %%
annotation_result = pd.read_excel("comment_annotation_gemini_final.xlsx")

# %%
sum(annotation_result['artwork id'].duplicated())
# Out:
# 0

# %%
check_point = annotation_result['artwork id'] == artnet_2024_Picasso.iloc[0:5000]['artwork id']

# %%
a = artnet_2024_Picasso.iloc[0:5000][annotation_result['artwork id'] != artnet_2024_Picasso.iloc[0:5000]['artwork id']]

# %%
a.shape
# Out:
# (0, 16)

# %%
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Start")
count=0
for i in range(5000):
    if not check_point[i]:
        content = {
            "artwork id": artnet_2024_Picasso.iloc[i]["artwork id"],
            "title": artnet_2024_Picasso.iloc[i]["title"],
            "first": artnet_2024_Picasso.iloc[i]["first"],
            "last": artnet_2024_Picasso.iloc[i]["last"],
            "workyear from": artnet_2024_Picasso.iloc[i]["workyear from"],
            "nationality": artnet_2024_Picasso.iloc[i]["nationality"]}
        _,result,error = annotation(i,content)
        annotation_result.loc[i,:] =result
        count+=1
        if count%50 ==0:
            print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Current at {count}")
print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}: Ends")
# Out:
# 2025-12-04 15:52:24: Start
# 2025-12-04 15:56:09: Current at 50
# 2025-12-04 15:59:33: Ends

# %%
annotation_result.to_excel("comment_annotation_gemini_fix.xlsx",index=False)

# %% [markdown]
# # Test on Prompt Sensitivity Code

# %%
with open("D:\\MissTiny\\GitHub\\Creativity_Chess\\Token_Key\\gemini_api.txt", "r", encoding="utf-8") as file:
    gemini_api = file.read()

# %%
row = artnet_2025.iloc[1]

# %%
instruction_message=f"""You are an expert in artwork criticism, art history, and creativity evaluation. 
Using web search, find authoritative commentary on the artistic value and creative significance of the artwork:
- Title: \'{row.title}\' 
- Artist:{row['first']} {row['last']} ({row.nationality})
- Year of Creation:{row['workyear from']} 

Based strictly on information gathered through web search, summarize the consensus and key scholarly interpretations regarding the artwork’s artistic value and creativity.
Your analysis should address innovations in composition, technique, emotional expression, iconography, and influences on later art.
- An artwork is creative only if it is new, valuable, and surprising compared to prior artworks

OUTPUT FORMAT(around 150 words each)
Artistic Value:
<Your summary here>
Creativity
<Your summary here>
"""

# %%
print(instruction_message)
# Out:
# You are an expert in artwork criticism, art history, and creativity evaluation.
# Using web search, find authoritative commentary on the artistic value and creative significance of the artwork:
# - Title: 'La Vierge d'humilité, tableau de dévotion'
# - Artist:Francesco di Gentile da Fabriano (Italian)
# - Year of Creation:1420
#
# Based strictly on information gathered through web search, summarize the consensus and key scholarly interpretations regarding the artwork’s artistic value and creativity.
# Your analysis should address innovations in composition, technique, emotional expression, iconography, and influences on later art.
# - An artwork is creative only if it is new, valuable, and surprising compared to prior artworks
#
# OUTPUT FORMAT(around 150 words each)
# Artistic Value:
# <Your summary here>
# Creativity
# <Your summary here>

# %%
gemini_client = genai.Client(
    api_key=gemini_api
)

# %%
response =gemini_client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=instruction_message,
    config={
            "tools": [
                {
                    "google_search": {}
                }
            ]
        }
)

# %%
print(response.text)
# Out:
# **Artistic Value:**
#
# Francesco di Gentile da Fabriano's "La Vierge d'humilité, tableau de dévotion" (c. 1420) is a significant work that bridges the International Gothic style with emerging Renaissance sensibilities. Artistically, its value lies in its delicate linearity, rich decorative elements, and vibrant colors, characteristic of the International Gothic style. The painting showcases Gentile's mastery in detailed representations, drawing from his observations of the natural world. The iconography of the Madonna of Humility itself, depicting Mary seated on the ground, emphasizes her humanity and approachability, a departure from the more formal, enthroned Madonnas. This particular work, though potentially intended for private devotion due to its scale, demonstrates a refinement and sophistication that speaks to the era's developing artistic tastes. The use of tempera and gold leaf, common for devotional pieces of the period, contributes to its preciousness and spiritual aura. While some scholarly interpretations note its "patterning and flattened space," the work is recognized for its contribution to the flourishing arts in early Renaissance Florence.
#
# **Creativity:**
#
# The creativity of "La Vierge d'humilité, tableau de dévotion" by Gentile da Fabriano, created around 1420, lies in its synthesis of existing traditions with nascent Renaissance innovations. The artwork adheres to the "Madonna of Humility" iconography, which originated in the 14th century, thus not entirely novel in its subject matter but refined in its execution. Gentile's creativity is evident in his masterful blend of the International Gothic style's elegance and ornamentation with a growing interest in naturalism, a hallmark of the early Renaissance. His detailed rendering of fabrics, and possibly elements of the natural world, hints at the observational skills that would become more prominent in later Renaissance art. Furthermore, the subtle inclusion of Arabic characters on the cloth is an intriguing, albeit unexplained, "exotic addition" that suggests an openness to diverse influences. This transitional nature, harmonizing courtly elegance with emerging realism and subtle foreign motifs, positions the work as a creative bridge between medieval traditions and the forward-looking artistic developments of the Renaissance.

# %%
prompt1=f"""You are an expert in artwork criticism, art history, and creativity evaluation.
Using web search, find authoritative commentary on the artistic value and creative significance of the artwork:
- Title: \'{row.title}\' 
- Artist:{row['first']} {row['last']} ({row.nationality})
- Year of Creation:{row['workyear from']} 

Based strictly on information gathered through web search, summarize the consensus and key scholarly interpretations in English regarding the artwork’s artistic value and creativity.
Your analysis should address innovations in composition, technique, emotional expression, iconography, and influences on later art.
- An artwork is creative only if it is new, valuable, and surprising compared to prior artworks

OUTPUT FORMAT(around 150 words each)
Artistic Value: 
<Your summary here>
Creativity: <Yes or No>
<Your summary here>
"""

# %%
response1 =gemini_client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=prompt1,
    config={
            "tools": [
                {
                    "google_search": {}
                }
            ]
        }
)

# %%
print(response1.text)
# Out:
# The artwork 'La Vierge d'humilité, tableau de dévotion' by Francesco di Gentile da Fabriano, created around 1420, is highly regarded for its artistic value, particularly within the International Gothic style. Scholars note Gentile da Fabriano's mastery in combining precious materials with a keen interest in naturalism, using real gold to create subtle lighting effects that lend the figures a lifelike quality. The use of light and the depiction of three-dimensional figures contribute to defining space and bringing the artwork to life. His detailed rendering of faces with varying expressions was also innovative for the time. The painting's decorative richness, evident in the luxurious fabrics and the inclusion of exotic elements and animals, speaks to the patron's wealth and status while contributing to an exotic setting for the biblical scene. The inclusion of Arabic imitation script further enhances its exoticism and luxury. These elements, combined with fine linearity and vibrant colors, make it a prime example of the International Gothic style, influencing Florentine artists and offering a counterpoint to the emerging austerity of the Renaissance.
#
# Creativity: Yes.
# Francesco di Gentile da Fabriano's 'La Vierge d'humilité, tableau de dévotion' (c. 1420) demonstrates creativity through several innovations. While rooted in the International Gothic style, Gentile incorporated a growing interest in naturalism, evident in his detailed observation of plants and animals, and the nuanced rendering of human expression. The technique of layering gold leaf beneath paint to create a subtle glow was novel and became influential. The painting also showcases an innovative use of light to define form and create a sense of depth and three-dimensionality. Furthermore, the inclusion of pseudo-Arabic script and exotic elements, while contributing to a sense of luxury, also represents a surprising and perhaps even experimental engagement with the "Orient" by an artist of this period. This blending of courtly refinement with naturalistic detail and exotic motifs presents a valuable and surprising departure from purely traditional representations, marking a significant step in artistic evolution.

# %%
prompt2=f"""Act as an expert in artwork criticism, art history, and creativity evaluation.
Using web search, summarize in English the artistic value and creative significance of {row['first']} {row['last']}’s {row['workyear from']}  artwork “{row.title}”.
Note that an artwork is creative only if it is new, valuable, and surprising compared to prior artworks

OUTPUT: (~150 words each)
Artistic Value:
<text>

Creativity: <Yes or No>
<text>
"""

# %%
response2 =gemini_client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=prompt2,
    config={
            "tools": [
                {
                    "google_search": {}
                }
            ]
        }
)

# %%
print(response2.text)
# Out:
# Artistic Value:
# Francesco di Gentile da Fabriano's "La Vierge d'humilité, tableau de dévotion" (1420) is a significant work within the context of early 15th-century Italian painting. Its value lies in its rich execution and devotional intensity. The painting likely exhibits the detailed and decorative style characteristic of the International Gothic, a style that was prevalent across Europe. This would involve meticulous rendering of fabrics, intricate patterns, and a jewel-like quality in the colors, creating a luxurious and aesthetically pleasing surface. The "humble Virgin" theme, a less monumental depiction of Mary and Child compared to previous portrayals, offers a more intimate and accessible devotional experience for the viewer. This focus on humanizing the divine, presenting a more tender and relatable Mary, contributes to its artistic merit by fostering a closer connection between the faithful and the sacred figures. The use of gold leaf or gilded elements, common in devotional works of this period, would have further enhanced its spiritual resonance and visual splendor.
#
# Creativity: Yes
# The artwork demonstrates creativity by presenting a new and valuable interpretation of a traditional religious subject. While depictions of the Virgin Mary and Christ Child were standard in religious art, Fabriano's "La Vierge d'humilité" likely introduced a fresh perspective through its specific style and emotional tone. The "humble Virgin" motif itself suggests a departure from more regal or idealized representations, opting instead for a more grounded and tender portrayal that emphasizes maternal affection and human connection. This shift towards greater naturalism and emotional resonance, even within the decorative framework of the International Gothic style, can be considered surprising and innovative for its time. The detailed execution, combined with this more intimate devotional focus, offers a valuable contribution to the evolving artistic landscape, making it a creative work that is new, valuable, and surprising compared to some of its predecessors.

# %%
prompt3=f"""ou are a general expert in artwork criticism, art history, and creativity evaluation.
Using web search, analyze the artwork:

- Title: '{row.title}'
- Artist: {row['first']} {row['last']} ({row.nationality})
- Year: {row['workyear from']}

Based ONLY on web search results, provide two ~150-word sections evaluating:
1. Artistic Value
2. Creativity

Note that an artwork is creative only if it is new, valuable, and surprising compared to prior artworks

OUTPUT:
Artistic Value:
<text>
Creativity: <Yes or No>
<text>
"""

# %%
response3 =gemini_client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=prompt3,
    config={
            "tools": [
                {
                    "google_search": {}
                }
            ]
        }
)

# %%
print(response3.text)
# Out:
# **Artistic Value:**
# Francesco di Gentile da Fabriano's "La Vierge d'humilité, tableau de dévotion" (circa 1420) is a significant work within the context of early Italian Renaissance devotional art. The painting exemplifies the International Gothic style with its elegant refinement and meticulous attention to detail, particularly in the rendering of fabrics and the surrounding flora, which carry symbolic meaning of the Virgin's virtues. While Gentile da Fabriano is recognized as a leading exponent of this style, his work also contributed to the emerging trends that foreshadowed the Renaissance, such as his unifying use of light to suggest dimension and perspective. The work's modest scale suggests it was intended for private devotion, a common practice for small devotional pictures produced in large numbers during this period for both churches and individuals. The use of a golden background, while a nod to older icon traditions, is here supplemented by a Tuscan panorama, indicating a move towards greater naturalism and atmospheric perspective, influenced by contemporary Flemish painting.
#
# **Creativity:** Yes
# This artwork demonstrates creativity through its nuanced portrayal of the "Madonna of Humility" theme, which was an invention of Simone Martini in the preceding century. While the theme itself was not new, Gentile da Fabriano's interpretation likely incorporated innovative elements for its time. The presence of Arabic inscriptions on the cloth where the Child lies is a particularly unusual and unexplained feature, suggesting an "exotic addition" possibly made without full understanding of its meaning, which adds an element of surprising originality. Furthermore, Gentile da Fabriano's work, while rooted in the International Gothic style, also shows an engagement with the developing Renaissance interest in naturalism and perspective, as seen in his use of light and atmospheric effects in the landscape. This fusion of established Gothic elegance with nascent Renaissance sensibilities can be seen as a creative bridge between artistic periods.

# %%
prompt4=f"""Assume the role of a comprehensive art expert with deep knowledge of global art history, visual analysis, and creativity theory.
Using web search, gather authoritative scholarly commentary on:

- '{row.title}' by {row['first']} {row['last']} ({row.nationality}), created in {row['workyear from']}.

Based strictly on verified search results, summarize the artwork’s:
1. Artistic Value — aesthetic qualities, emotional resonance, technical execution, symbolism, and critical reception.
2. Creativity — an artwork is creative only if it is new, valuable, and surprising compared to prior artworks.

Write ~150 words per section, in English.

FORMAT:
Artistic Value:
<text>

Creativity: <Yes or No>
<text>
"""

# %%
response4 =gemini_client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=prompt4,
    config={
            "tools": [
                {
                    "google_search": {}
                }
            ]
        }
)

# %%
print(response4.text)
# Out:
# **Artistic Value:**
# "La Vierge d'humilité" by Francesco di Gentile da Fabriano, created around 1420, is a devotional painting that exemplifies the transition from Gothic aesthetics to early Renaissance sensibilities. The artwork is noted for its meticulous detail, particularly in the depiction of flora, which serves a dual purpose: symbolic and naturalistic. The strawberries and violets, for instance, are rendered with a descriptive precision that links to a search for truth while retaining a Gothic decorative spirit. This naturalistic observation aligns with the contemporary interest in the tangible world, moving away from purely abstract representations. The composition itself, featuring the Virgin Mary seated on the ground, emphasizes her humanity and humility, a departure from the more formal and distant depictions of the "Maestà." The refined execution, characteristic of the Sienese and International Gothic styles, is evident in the elegant lines of Mary's mantle and the decorative elements. While rooted in Gothic tradition, the painting also shows an engagement with the three-dimensional research occurring in Florence, evident in the shift from a gold background to a Tuscan landscape, creating an atmospheric perspective that suggests an awareness of contemporary Flemish painting. This sophisticated blend of detailed naturalism, courtly elegance, and emerging Renaissance spatial awareness contributes to its significant artistic merit.
#
# **Creativity:** Yes
# Francesco di Gentile da Fabriano's "La Vierge d'humilité" can be considered creative because it introduces new value and surprising elements compared to prior artworks. The iconography of the "Virgin of Humility," where Mary is depicted seated on the ground, was a Sienese invention from the 1340s, making her appear more human and approachable than in the traditional enthroned Maestà. Fabriano's rendition, created around 1420, builds upon this, showing a precise, almost scientific, observation of nature in the surrounding flora, such as strawberries and violets symbolizing virtues. This detailed naturalism, combined with a decorative Gothic spirit, was innovative for its time. Furthermore, the painting's departure from the traditional gold background to a Tuscan landscape with atmospheric perspective demonstrates an engagement with contemporary developments in Florence and possibly Flemish painting, offering a surprising depth and realism. The incorporation of a luxurious brocade cushion, despite the theme of humility, adds a surprising element of courtly richness. These elements—the humanized depiction of Mary, the detailed and symbolic naturalism, and the innovative use of landscape and perspective—represent a valuable and surprising evolution from earlier devotional art.

# %%
tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-base-patch32")
text_model = CLIPTextModel.from_pretrained("openai/clip-vit-base-patch32")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = text_model.to(device)

# %%
texts=[response1.text,response2.text,response3.text,response4.text]

# %%
inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt").to(device)
with torch.no_grad():
    outputs = model(**inputs)
text_embeds = outputs.pooler_output
text_embeds = text_embeds / text_embeds.norm(dim=-1, keepdim=True)
text_embeds=text_embeds.cpu().numpy()

# %%
pairwise = cosine_similarity(text_embeds)

# %%
pairwise
# Out:
# array([[1.0000002 , 0.9281757 , 0.87428695, 0.90575755],
#        [0.9281757 , 0.9999999 , 0.9134153 , 0.9188012 ],
#        [0.87428695, 0.9134153 , 1.0000005 , 0.9176482 ],
#        [0.90575755, 0.9188012 , 0.9176482 , 1.0000001 ]], dtype=float32)
